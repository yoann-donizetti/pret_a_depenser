# %% [markdown]
# # Préparation des données pour l’API + Packaging MLflow
#
# ## Objectif
#
# Cette étape prépare un dataset exploitable en production pour alimenter l’API de scoring (Gradio) et la base SQLite.

# %% [markdown]
# ## Chargement des données de production simulées
#
# Nous utilisons `test_final.csv` (dataset Kaggle sans variable TARGET) comme proxy de données réelles en production.
#
# Ce fichier représente des demandes clients pour lesquelles on souhaite produire un score de défaut via l’API.

# %%
from pathlib import Path
import pandas as pd
import sys
CWD = Path.cwd()
PROJECT_ROOT = CWD.parent.parent
DATA_PROCESSED = PROJECT_ROOT / "data" / "processed"
sys.path.append(str(PROJECT_ROOT))
df = pd.read_csv(DATA_PROCESSED / "test_final.csv")

# %% [markdown]
# ## Création du dataset API-ready
#
# Nous construisons un dataset `X_api.csv` contenant :
# - `SK_ID_CURR` (identifiant client),
# - les 125 features retenues.
#
# Ce fichier sera ensuite utilisé pour alimenter une base SQLite locale afin de simuler le stockage des données en production.
#
# La colonne **SK_ID_CURR** est indispensable pour pouvoir interroger un client spécifique via l’API.

# %%
FEATURE_REDUCTION_DIR = PROJECT_ROOT / "reports" / "feature_reduction"
FEATURE_SET_NAME = "top125_nocorr"
kept_file = FEATURE_REDUCTION_DIR / f"kept_features_{FEATURE_SET_NAME}.txt"

kept_features = [
    l.strip()
    for l in kept_file.read_text(encoding="utf-8").splitlines()
    if l.strip()
]
kept_features = [c for c in kept_features if c in df.columns]
if len(kept_features) == 0:
    raise ValueError(f"kept_features vide -> vérifie le contenu de: {kept_file}")


cols = ["SK_ID_CURR"] + kept_features
missing = [c for c in cols if c not in df.columns]
if missing:
    raise ValueError(f"Colonnes manquantes dans test_final.csv: {missing[:10]}")

# %% [markdown]
# ## Export du fichier `X_api.csv`
#
# Le fichier est exporté dans `app/asset/`.
#
# Il constitue une source standardisée pour :
# - initialiser la base SQLite,
# - simuler des appels API,
# - générer des données de monitoring (logs de prédiction, scores, latence, drift).

# %%
X_api = df[cols].copy()
out_path = DATA_PROCESSED/ "X_api.csv"
X_api.to_csv(out_path, index=False)

print("OK:", out_path, X_api.shape)
# Out:
# OK: c:\Users\yoann\Documents\open classrooms\projet 8\livrables\pret a dépenser\data\processed\X_api.csv (48744, 126)

# %%
import json
row = X_api.iloc[3].to_dict()

# Remplacer les NaN par None (=> null en JSON)
row = {k: (None if pd.isna(v) else v) for k, v in row.items()}

# Export JSON formaté
json_text = json.dumps(row, indent=2)

print(json_text)
# Out:
# {
#   "SK_ID_CURR": 100028,
#   "EXT_SOURCE_3": 0.6127042441012546,
#   "EXT_SOURCE_2": 0.5096770801723647,
#   "ORGANIZATION_TYPE": "Business Entity Type 3",
#   "EXT_SOURCE_1": 0.5257339776824489,
#   "BUREAU_BUREAU_DEBT_RATIO_MAX": 0.838975,
#   "DAYS_EMPLOYED": -1866.0,
#   "AMT_CREDIT": 1575000.0,
#   "OCCUPATION_TYPE": "Sales staff",
#   "PREV_RATIO_REFUSED": 0.0,
#   "PREV_INST_AMT_PAYMENT_MIN_SUM": 12704.67,
#   "AMT_ANNUITY": 49018.5,
#   "PREV_INST_AMT_PAYMENT_MIN_MEAN": 4234.89,
#   "CODE_GENDER": "F",
#   "NAME_EDUCATION_TYPE": "Secondary / secondary special",
#   "AMT_GOODS_PRICE": 1575000.0,
#   "DAYS_BIRTH": -13976,
#   "OWN_CAR_AGE": null,
#   "BUREAU_BUREAU_DEBT_RATIO_STD": 0.2777859517559874,
#   "PREV_PREV_CREDIT_TO_APPLICATION_MEAN": 0.9674785654181164,
#   "PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN": 8.3125,
#   "PREV_POS_INSTALMENT_FUTURE_MEAN_STD": 4.684582425360877,
#   "BUREAU_BUREAU_DEBT_RATIO_MEAN": 0.1222668319328298,
#   "PREV_INST_RATIO_EARLY_MEAN": 0.7698412698412698,
#   "PREV_INST_RATIO_LATE_MEAN": 0.0476190476190475,
#   "PREV_POS_INSTALMENT_FUTURE_MEAN_MAX": 11.625,
#   "PREV_INST_INST_DAYSLATE_MAX_MEAN": 1.6666666666666667,
#   "FLAG_DOCUMENT_3": true,
#   "PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN": 0.9674785654181164,
#   "REGION_RATING_CLIENT_W_CITY": 2,
#   "NAME_FAMILY_STATUS": "Married",
#   "PREV_PREV_CREDIT_TO_GOODSPRICE_MAX": 1.0,
#   "PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM": 0.0454545454545454,
#   "NAME_CONTRACT_TYPE": "Cash loans",
#   "PREV_CC_CC_UTILIZATION_MAX_MAX": 0.1659374,
#   "BUREAU_AMT_CREDIT_SUM_MAX": 393750.0,
#   "PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX": 0.0454545454545454,
#   "BUREAU_BUREAU_DEBT_RATIO_SUM": 1.1004014873954688,
#   "DAYS_ID_PUBLISH": -4208,
#   "PREV_INST_COUNT_EARLY_SUM": 55.0,
#   "BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX": 0.0,
#   "PREV_PREV_CREDIT_TO_APPLICATION_MAX": 1.0,
#   "PREV_INST_COUNT_LATE_MEAN": 4.0,
#   "PREV_INST_RATIO_LATE_MIN": 0.0,
#   "BUREAU_CREDIT_TYPE_Microloan": 0.0,
#   "DEF_60_CNT_SOCIAL_CIRCLE": 0.0,
#   "PREV_INST_AMT_PAYMENT_SUM_SUM": 492310.665,
#   "PREV_DAYS_DECISION_MEAN": -1124.2,
#   "PREV_POS_MONTHS_MAX_MAX": -20.0,
#   "BUREAU_DAYS_CREDIT_MEAN": -1401.75,
#   "PREV_INST_AMT_PAYMENT_SUM_MEAN": 164103.55500000002,
#   "PREV_RATIO_APPROVED": 0.6,
#   "BUREAU_AMT_CREDIT_SUM_MEAN": 126739.59,
#   "PREV_INST_COUNT_EARLY_MEAN": 18.33333333333333,
#   "PREV_INST_AMT_INSTALMENT_MIN_MIN": 1.17,
#   "PREV_INST_INST_DAYSLATE_MAX_MAX": 7.0,
#   "BUREAU_CREDIT_TYPE_Mortgage": 0.0,
#   "BUREAU_DAYS_CREDIT_ENDDATE_MAX": 30885.0,
#   "PREV_INST_RATIO_LATE_SUM": 0.1428571428571428,
#   "BUREAU_BUREAU_REAL_DELAY_MEAN": -61.16666666666666,
#   "PREV_CC_CC_UTILIZATION_MAX_MEAN": 0.1659374,
#   "DAYS_LAST_PHONE_CHANGE": -1805.0,
#   "PREV_AMT_DOWN_PAYMENT_SUM": 11250.0,
#   "PREV_CNT_PAYMENT_STD": 12.055427546683417,
#   "PREV_INST_AMT_PAYMENT_MIN_MAX": 6996.735,
#   "BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM": 0.0,
#   "PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN": 0.0454545454545454,
#   "BUREAU_AMT_CREDIT_SUM_SUM": 1520875.08,
#   "PREV_AMT_ANNUITY_MIN": 6028.02,
#   "PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN": 0.0454545454545454,
#   "PREV_DAYS_LAST_DUE_1ST_VERSION_MAX": 365243.0,
#   "PREV_PREV_DECISION_TO_FIRST_DUE_MEAN": 93.0,
#   "BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN": 0.0,
#   "BUREAU_DAYS_ENDDATE_FACT_MAX": -687.0,
#   "BUREAU_AMT_CREDIT_MAX_OVERDUE_STD": 0.0,
#   "PREV_AMT_ANNUITY_MEAN": 8091.585,
#   "PREV_INST_INST_DAYSLATE_SUM_MAX": -29.0,
#   "PREV_INST_RATIO_LATE_MAX": 0.1428571428571428,
#   "PREV_CC_CC_UTILIZATION_MEAN_SUM": 0.0359335918367346,
#   "PREV_CC_CC_UTILIZATION_MEAN_MEAN": 0.0359335918367346,
#   "PREV_AMT_DOWN_PAYMENT_MAX": 11250.0,
#   "BUREAU_AMT_CREDIT_SUM_MIN": 0.0,
#   "PREV_INST_AMT_INSTALMENT_MIN_MEAN": 4234.89,
#   "PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN": 2.841774141642654,
#   "BUREAU_DAYS_CREDIT_MAX": -269.0,
#   "REG_CITY_NOT_LIVE_CITY": false,
#   "PREV_INST_COUNT_OVERPAID_STD": 0.0,
#   "PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN": -279.15964285714284,
#   "PREV_INST_INST_DAYSLATE_MAX_MIN": -1.0,
#   "AMT_INCOME_TOTAL": 315000.0,
#   "PREV_SELLERPLACE_AREA_MEAN": 1409.6,
#   "PREV_POS_SK_DPD_DEF_MAX_MEAN": 0.0,
#   "PREV_INST_AMT_PAYMENT_MIN_MIN": 1.17,
#   "PREV_INST_AMT_PAYMENT_SUM_MAX": 283724.46,
#   "BUREAU_AMT_CREDIT_SUM_STD": 104551.23558591184,
#   "PREV_INST_DAYS_INSTALMENT_MAX_STD": 530.6075134535256,
#   "DEF_30_CNT_SOCIAL_CIRCLE": 0.0,
#   "PREV_CC_CC_UTILIZATION_MEAN_MAX": 0.0359335918367346,
#   "PREV_INST_RATIO_EARLY_MAX": 1.0,
#   "PREV_INST_AMT_INSTALMENT_SUM_SUM": 562658.895,
#   "PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX": -29.0,
#   "AMT_REQ_CREDIT_BUREAU_QRT": 0.0,
#   "PREV_INST_INST_PAYMENTDIFF_MIN_MEAN": -2835.0,
#   "BUREAU_DAYS_CREDIT_SUM": -16821.0,
#   "BUREAU_DAYS_CREDIT_MIN": -2105.0,
#   "BUREAU_DAYS_ENDDATE_FACT_STD": 507.455651358065,
#   "PREV_INST_DAYS_INSTALMENT_MAX_MAX": -27.0,
#   "APARTMENTS_MODE": 0.3109,
#   "BUREAU_DAYS_CREDIT_UPDATE_MAX": -20.0,
#   "PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN": -59015.0,
#   "PREV_INST_AMT_PAYMENT_MEAN_MIN": 3377.672142857143,
#   "PREV_INST_INST_DAYSLATE_MAX_SUM": 5.0,
#   "PREV_INST_COUNT_OVERPAID_MEAN": 0.0,
#   "BUREAU_BUREAU_CREDIT_DURATION_MAX": 32706.0,
#   "PREV_INST_INST_PAYMENTRATIO_SUM_MEAN": 34.333333333333336,
#   "PREV_CC_CC_UTILIZATION_MAX_SUM": 0.1659374,
#   "PREV_NAME_PRODUCT_TYPE_walk-in": 0.0,
#   "PREV_POS_SK_DPD_DEF_SUM_MEAN": 0.0,
#   "PREV_POS_INSTALMENT_FUTURE_MAX_MEAN": 17.0,
#   "PREV_POS_STATUS_ACTIVE_RATIO_STD": 0.0715524719057816,
#   "PREV_POS_STATUS_ACTIVE_MEAN": 14.5,
#   "PREV_INST_DAYS_INSTALMENT_SUM_MIN": -58875.0,
#   "PREV_CNT_PAYMENT_MEAN": 11.333333333333334,
#   "PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN": 121221.33333333331,
#   "PREV_INST_AMT_PAYMENT_SUM_MIN": 66975.48,
#   "PREV_POS_SK_DPD_DEF_MEAN_SUM": 0.0
# }

# %%
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

X_api.describe().T
# Out:
#                                               count          mean  \
# SK_ID_CURR                                  48744.0  2.777967e+05
# EXT_SOURCE_3                                40076.0  5.001056e-01
# EXT_SOURCE_2                                48736.0  5.180211e-01
# EXT_SOURCE_1                                28212.0  5.011798e-01
# BUREAU_BUREAU_DEBT_RATIO_MAX                41096.0  3.039704e+00
# DAYS_EMPLOYED                               39470.0 -2.476739e+03
# AMT_CREDIT                                  48744.0  5.167404e+05
# PREV_RATIO_REFUSED                          47800.0  1.145769e-01
# PREV_INST_AMT_PAYMENT_MIN_SUM               47800.0  4.599559e+04
# AMT_ANNUITY                                 48720.0  2.942624e+04
# PREV_INST_AMT_PAYMENT_MIN_MEAN              47528.0  1.508186e+04
# AMT_GOODS_PRICE                             48744.0  4.626188e+05
# DAYS_BIRTH                                  48744.0 -1.606808e+04
# OWN_CAR_AGE                                 16432.0  1.178603e+01
# BUREAU_BUREAU_DEBT_RATIO_STD                34542.0  1.245993e+00
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN        47710.0  1.020343e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN        47387.0  8.937964e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD         32491.0  6.136017e+00
# BUREAU_BUREAU_DEBT_RATIO_MEAN               41096.0  5.129628e-01
# PREV_INST_RATIO_EARLY_MEAN                  47529.0  8.596568e-01
# PREV_INST_RATIO_LATE_MEAN                   47529.0  5.844804e-02
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX         47387.0  1.373659e+01
# PREV_INST_INST_DAYSLATE_MAX_MEAN            47528.0  4.082260e-02
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN         47710.0  1.020299e+00
# REGION_RATING_CLIENT_W_CITY                 48744.0  2.012596e+00
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX          47710.0  1.111273e+00
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM   47800.0  9.709977e-02
# PREV_CC_CC_UTILIZATION_MAX_MAX              14266.0  5.422329e-01
# BUREAU_AMT_CREDIT_SUM_MAX                   42319.0  1.089840e+06
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX    9094.0  5.091874e-01
# BUREAU_BUREAU_DEBT_RATIO_SUM                42320.0  3.445678e+00
# DAYS_ID_PUBLISH                             48744.0 -3.051713e+03
# PREV_INST_COUNT_EARLY_SUM                   47800.0  2.732787e+01
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX           29085.0  6.584804e+03
# PREV_PREV_CREDIT_TO_APPLICATION_MAX         47710.0  1.111486e+00
# PREV_INST_COUNT_LATE_MEAN                   47529.0  9.739729e-01
# PREV_INST_RATIO_LATE_MIN                    47529.0  2.131307e-02
# BUREAU_CREDIT_TYPE_Microloan                42320.0  8.052930e-02
# DEF_60_CNT_SOCIAL_CIRCLE                    48715.0  1.011393e-01
# PREV_INST_AMT_PAYMENT_SUM_SUM               47800.0  7.422276e+05
# PREV_DAYS_DECISION_MEAN                     47800.0 -9.175523e+02
# PREV_POS_MONTHS_MAX_MAX                     47392.0 -1.214407e+01
# BUREAU_DAYS_CREDIT_MEAN                     42320.0 -1.088503e+03
# PREV_INST_AMT_PAYMENT_SUM_MEAN              47529.0  2.342612e+05
# PREV_RATIO_APPROVED                         47800.0  7.179468e-01
# BUREAU_AMT_CREDIT_SUM_MEAN                  42319.0  3.972991e+05
# PREV_INST_COUNT_EARLY_MEAN                  47529.0  9.369381e+00
# PREV_INST_AMT_INSTALMENT_MIN_MIN            47529.0  8.131514e+03
# PREV_INST_INST_DAYSLATE_MAX_MAX             47528.0  9.562300e+00
# BUREAU_CREDIT_TYPE_Mortgage                 42320.0  6.578450e-02
# BUREAU_DAYS_CREDIT_ENDDATE_MAX              41984.0  4.979068e+03
# PREV_INST_RATIO_LATE_SUM                    47800.0  1.753976e-01
# BUREAU_BUREAU_REAL_DELAY_MEAN               37569.0 -5.020158e+02
# PREV_CC_CC_UTILIZATION_MAX_MEAN             14266.0  5.404827e-01
# DAYS_LAST_PHONE_CHANGE                      48744.0 -1.077766e+03
# PREV_AMT_DOWN_PAYMENT_SUM                   47800.0  1.602647e+04
# PREV_CNT_PAYMENT_STD                        38018.0  1.025658e+01
# PREV_INST_AMT_PAYMENT_MIN_MAX               47528.0  3.119308e+04
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM           42320.0  5.359891e+03
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN   9094.0  5.074497e-01
# BUREAU_AMT_CREDIT_SUM_SUM                   42320.0  2.220714e+06
# PREV_AMT_ANNUITY_MIN                        47737.0  8.209044e+03
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN    9094.0  5.057120e-01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX          47580.0  1.120770e+05
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN        47580.0  1.459370e+04
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN          29085.0  3.503427e+03
# BUREAU_DAYS_ENDDATE_FACT_MAX                37800.0 -5.056957e+02
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD           18002.0  4.145082e+03
# PREV_AMT_ANNUITY_MEAN                       47737.0  1.541084e+04
# PREV_INST_INST_DAYSLATE_SUM_MAX             47529.0 -6.644297e+01
# PREV_INST_RATIO_LATE_MAX                    47529.0  1.189454e-01
# PREV_CC_CC_UTILIZATION_MEAN_SUM             47800.0  8.534943e-02
# PREV_CC_CC_UTILIZATION_MEAN_MEAN            14266.0  2.839476e-01
# PREV_AMT_DOWN_PAYMENT_MAX                   45148.0  1.228880e+04
# BUREAU_AMT_CREDIT_SUM_MIN                   42319.0  1.145575e+05
# PREV_INST_AMT_INSTALMENT_MIN_MEAN           47529.0  1.712839e+04
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN       14452.0  1.956272e+00
# BUREAU_DAYS_CREDIT_MAX                      42320.0 -5.011833e+02
# PREV_INST_COUNT_OVERPAID_STD                34232.0  3.873136e-01
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN        47528.0  7.268850e+02
# PREV_INST_INST_DAYSLATE_MAX_MIN             47528.0 -7.187553e+00
# AMT_INCOME_TOTAL                            48744.0  1.784318e+05
# PREV_SELLERPLACE_AREA_MEAN                  47800.0  4.124655e+02
# PREV_POS_SK_DPD_DEF_MAX_MEAN                47392.0  3.195973e-01
# PREV_INST_AMT_PAYMENT_MIN_MIN               47528.0  6.232510e+03
# PREV_INST_AMT_PAYMENT_SUM_MAX               47529.0  4.423748e+05
# BUREAU_AMT_CREDIT_SUM_STD                   36871.0  4.496771e+05
# PREV_INST_DAYS_INSTALMENT_MAX_STD           34232.0  6.365931e+02
# DEF_30_CNT_SOCIAL_CIRCLE                    48715.0  1.436519e-01
# PREV_CC_CC_UTILIZATION_MEAN_MAX             14266.0  2.851661e-01
# PREV_INST_RATIO_EARLY_MAX                   47529.0  9.550787e-01
# PREV_INST_AMT_INSTALMENT_SUM_SUM            47800.0  7.269910e+05
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX        47528.0 -3.322957e+02
# AMT_REQ_CREDIT_BUREAU_QRT                   42695.0  5.469024e-01
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN         47528.0 -2.930058e+03
# BUREAU_DAYS_CREDIT_SUM                      42320.0 -6.724937e+03
# BUREAU_DAYS_CREDIT_MIN                      42320.0 -1.776740e+03
# BUREAU_DAYS_ENDDATE_FACT_STD                29629.0  5.355903e+02
# PREV_INST_DAYS_INSTALMENT_MAX_MAX           47529.0 -3.230409e+02
# APARTMENTS_MODE                             24857.0  1.190780e-01
# BUREAU_DAYS_CREDIT_UPDATE_MAX               42320.0 -1.288561e+02
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN        47529.0 -2.040541e+04
# PREV_INST_AMT_PAYMENT_MEAN_MIN              47528.0  1.206789e+04
# PREV_INST_INST_DAYSLATE_MAX_SUM             47800.0  8.707113e-01
# PREV_INST_COUNT_OVERPAID_MEAN               47529.0  2.432230e-01
# BUREAU_BUREAU_CREDIT_DURATION_MAX           41984.0  5.819137e+03
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN        47529.0  1.576228e+01
# PREV_CC_CC_UTILIZATION_MAX_SUM              47800.0  1.624554e-01
# PREV_NAME_PRODUCT_TYPE_walk-in              47800.0  4.603975e-01
# PREV_POS_SK_DPD_DEF_SUM_MEAN                47392.0  5.261976e-01
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN         47387.0  1.445438e+01
# PREV_POS_STATUS_ACTIVE_RATIO_STD            32524.0  8.452176e-02
# PREV_POS_STATUS_ACTIVE_MEAN                 47392.0  9.952016e+00
# PREV_INST_DAYS_INSTALMENT_SUM_MIN           47529.0 -2.025565e+04
# PREV_CNT_PAYMENT_MEAN                       47737.0  1.454900e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN         47580.0  3.248992e+04
# PREV_INST_AMT_PAYMENT_SUM_MIN               47529.0  1.069361e+05
# PREV_POS_SK_DPD_DEF_MEAN_SUM                47800.0  1.112126e-01
#
#                                                      std            min  \
# SK_ID_CURR                                  1.031695e+05  100001.000000
# EXT_SOURCE_3                                1.894980e-01       0.000527
# EXT_SOURCE_2                                1.812781e-01       0.000008
# EXT_SOURCE_1                                2.051423e-01       0.013458
# BUREAU_BUREAU_DEBT_RATIO_MAX                1.678111e+02       0.000000
# DAYS_EMPLOYED                               2.307964e+03  -17463.000000
# AMT_CREDIT                                  3.653970e+05   45000.000000
# PREV_RATIO_REFUSED                          1.798921e-01       0.000000
# PREV_INST_AMT_PAYMENT_MIN_SUM               1.097801e+05       0.000000
# AMT_ANNUITY                                 1.601637e+04    2295.000000
# PREV_INST_AMT_PAYMENT_MIN_MEAN              3.312666e+04       0.000000
# AMT_GOODS_PRICE                             3.367102e+05   45000.000000
# DAYS_BIRTH                                  4.325900e+03  -25195.000000
# OWN_CAR_AGE                                 1.146289e+01       0.000000
# BUREAU_BUREAU_DEBT_RATIO_STD                5.562186e+01       0.000000
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN        9.777146e-02       0.100000
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN        5.991956e+00       0.000000
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD         6.168549e+00       0.000000
# BUREAU_BUREAU_DEBT_RATIO_MEAN               1.666635e+01       0.000000
# PREV_INST_RATIO_EARLY_MEAN                  1.605712e-01       0.000000
# PREV_INST_RATIO_LATE_MEAN                   9.568376e-02       0.000000
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX         1.148673e+01       0.000000
# PREV_INST_INST_DAYSLATE_MAX_MEAN            3.019590e+01     -81.333333
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN         9.746636e-02       0.100000
# REGION_RATING_CLIENT_W_CITY                 5.158041e-01      -1.000000
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX          1.811360e-01       0.100000
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM   3.694545e-01       0.000000
# PREV_CC_CC_UTILIZATION_MAX_MAX              4.863603e-01       0.000000
# BUREAU_AMT_CREDIT_SUM_MAX                   3.415317e+06       0.000000
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX   7.097003e-01       0.000000
# BUREAU_BUREAU_DEBT_RATIO_SUM                1.656008e+02       0.000000
# DAYS_ID_PUBLISH                             1.569277e+03   -6348.000000
# PREV_INST_COUNT_EARLY_SUM                   2.377952e+01       0.000000
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX           7.978567e+04       0.000000
# PREV_PREV_CREDIT_TO_APPLICATION_MAX         1.830489e-01       0.100000
# PREV_INST_COUNT_LATE_MEAN                   1.891791e+00       0.000000
# PREV_INST_RATIO_LATE_MIN                    7.523413e-02       0.000000
# BUREAU_CREDIT_TYPE_Microloan                8.280617e-01       0.000000
# DEF_60_CNT_SOCIAL_CIRCLE                    4.037912e-01       0.000000
# PREV_INST_AMT_PAYMENT_SUM_SUM               9.904318e+05       0.000000
# PREV_DAYS_DECISION_MEAN                     5.553682e+02   -2921.000000
# PREV_POS_MONTHS_MAX_MAX                     1.721768e+01     -93.000000
# BUREAU_DAYS_CREDIT_MEAN                     5.269829e+02   -2921.000000
# PREV_INST_AMT_PAYMENT_SUM_MEAN              2.538890e+05       0.000000
# PREV_RATIO_APPROVED                         2.672446e-01       0.000000
# BUREAU_AMT_CREDIT_SUM_MEAN                  7.976595e+05       0.000000
# PREV_INST_COUNT_EARLY_MEAN                  5.058246e+00       0.000000
# PREV_INST_AMT_INSTALMENT_MIN_MIN            1.658134e+04       0.000000
# PREV_INST_INST_DAYSLATE_MAX_MAX             7.211117e+01     -30.000000
# BUREAU_CREDIT_TYPE_Mortgage                 2.719968e-01       0.000000
# BUREAU_DAYS_CREDIT_ENDDATE_MAX              9.844671e+03   -2759.000000
# PREV_INST_RATIO_LATE_SUM                    3.021562e-01       0.000000
# BUREAU_BUREAU_REAL_DELAY_MEAN               1.842236e+03  -33286.000000
# PREV_CC_CC_UTILIZATION_MAX_MEAN             4.856423e-01       0.000000
# DAYS_LAST_PHONE_CHANGE                      8.789207e+02   -4361.000000
# PREV_AMT_DOWN_PAYMENT_SUM                   4.926010e+04       0.000000
# PREV_CNT_PAYMENT_STD                        7.550866e+00       0.000000
# PREV_INST_AMT_PAYMENT_MIN_MAX               9.635192e+04       0.000000
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM           6.702934e+04       0.000000
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN  7.071757e-01       0.000000
# BUREAU_AMT_CREDIT_SUM_SUM                   4.537975e+06       0.000000
# PREV_AMT_ANNUITY_MIN                        8.263579e+03       0.000000
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN   7.067582e-01       0.000000
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX          1.685887e+05   -2796.000000
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN        4.166299e+04       1.000000
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN          6.344184e+04       0.000000
# BUREAU_DAYS_ENDDATE_FACT_MAX                5.028758e+02   -2857.000000
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD           4.705389e+04       0.000000
# PREV_AMT_ANNUITY_MEAN                       1.057334e+04     885.780000
# PREV_INST_INST_DAYSLATE_SUM_MAX             2.384695e+02   -5566.000000
# PREV_INST_RATIO_LATE_MAX                    1.657438e-01       0.000000
# PREV_CC_CC_UTILIZATION_MEAN_SUM             2.218415e-01      -0.002887
# PREV_CC_CC_UTILIZATION_MEAN_MEAN            3.252968e-01      -0.002887
# PREV_AMT_DOWN_PAYMENT_MAX                   2.954744e+04       0.000000
# BUREAU_AMT_CREDIT_SUM_MIN                   5.172363e+05       0.000000
# PREV_INST_AMT_INSTALMENT_MIN_MEAN           3.279299e+04       0.450000
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN       3.416548e+00       0.000000
# BUREAU_DAYS_CREDIT_MAX                      5.075073e+02   -2921.000000
# PREV_INST_COUNT_OVERPAID_STD                1.243440e+00       0.000000
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN        6.019692e+03  -89733.145500
# PREV_INST_INST_DAYSLATE_MAX_MIN             1.763567e+01    -241.000000
# AMT_INCOME_TOTAL                            1.015226e+05   26941.500000
# PREV_SELLERPLACE_AREA_MEAN                  2.409429e+03      -1.000000
# PREV_POS_SK_DPD_DEF_MAX_MEAN                1.412206e+00       0.000000
# PREV_INST_AMT_PAYMENT_MIN_MIN               1.659524e+04       0.000000
# PREV_INST_AMT_PAYMENT_SUM_MAX               5.734117e+05       0.000000
# BUREAU_AMT_CREDIT_SUM_STD                   1.226472e+06       0.000000
# PREV_INST_DAYS_INSTALMENT_MAX_STD           3.850143e+02       0.000000
# DEF_30_CNT_SOCIAL_CIRCLE                    5.144128e-01       0.000000
# PREV_CC_CC_UTILIZATION_MEAN_MAX             3.261981e-01      -0.002887
# PREV_INST_RATIO_EARLY_MAX                   1.219737e-01       0.000000
# PREV_INST_AMT_INSTALMENT_SUM_SUM            9.446391e+05       0.000000
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX        5.239280e+02   -2859.000000
# AMT_REQ_CREDIT_BUREAU_QRT                   6.933054e-01       0.000000
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN         6.314749e+03 -223029.000000
# BUREAU_DAYS_CREDIT_SUM                      6.254762e+03  -83611.000000
# BUREAU_DAYS_CREDIT_MIN                      8.299411e+02   -2922.000000
# BUREAU_DAYS_ENDDATE_FACT_STD                3.022448e+02       0.000000
# PREV_INST_DAYS_INSTALMENT_MAX_MAX           5.248757e+02   -2850.000000
# APARTMENTS_MODE                             1.134647e-01       0.000000
# BUREAU_DAYS_CREDIT_UPDATE_MAX               3.183699e+02   -2907.000000
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN        2.756906e+04 -300606.000000
# PREV_INST_AMT_PAYMENT_MEAN_MIN              2.231350e+04       0.090000
# PREV_INST_INST_DAYSLATE_MAX_SUM             7.577240e+01    -244.000000
# PREV_INST_COUNT_OVERPAID_MEAN               1.021813e+00       0.000000
# BUREAU_BUREAU_CREDIT_DURATION_MAX           9.905270e+03       0.000000
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN        1.898137e+02       0.000000
# PREV_CC_CC_UTILIZATION_MAX_SUM              3.658138e-01       0.000000
# PREV_NAME_PRODUCT_TYPE_walk-in              1.081010e+00       0.000000
# PREV_POS_SK_DPD_DEF_SUM_MEAN                2.707816e+00       0.000000
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN         7.702938e+00       0.000000
# PREV_POS_STATUS_ACTIVE_RATIO_STD            7.338888e-02       0.000000
# PREV_POS_STATUS_ACTIVE_MEAN                 4.978497e+00       0.000000
# PREV_INST_DAYS_INSTALMENT_SUM_MIN           2.752877e+04 -299543.000000
# PREV_CNT_PAYMENT_MEAN                       8.342980e+00       0.000000
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN         5.781678e+04   -2796.000000
# PREV_INST_AMT_PAYMENT_SUM_MIN               1.665503e+05       0.000000
# PREV_POS_SK_DPD_DEF_MEAN_SUM                5.062794e-01       0.000000
#
#                                                       25%           50%  \
# SK_ID_CURR                                  188557.750000  2.775490e+05
# EXT_SOURCE_3                                     0.363945  5.190973e-01
# EXT_SOURCE_2                                     0.408066  5.587579e-01
# EXT_SOURCE_1                                     0.343695  5.067713e-01
# BUREAU_BUREAU_DEBT_RATIO_MAX                     0.000000  7.547850e-01
# DAYS_EMPLOYED                                -3328.750000 -1.765000e+03
# AMT_CREDIT                                  260640.000000  4.500000e+05
# PREV_RATIO_REFUSED                               0.000000  0.000000e+00
# PREV_INST_AMT_PAYMENT_MIN_SUM                 9203.523750  2.097619e+04
# AMT_ANNUITY                                  17973.000000  2.619900e+04
# PREV_INST_AMT_PAYMENT_MIN_MEAN                5029.952813  8.946083e+03
# AMT_GOODS_PRICE                             225000.000000  3.960000e+05
# DAYS_BIRTH                                  -19637.000000 -1.578500e+04
# OWN_CAR_AGE                                      4.000000  9.000000e+00
# BUREAU_BUREAU_DEBT_RATIO_STD                     0.107714  3.389754e-01
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN             0.977664  1.025560e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN             5.075577  7.000000e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD              1.857048  3.889087e+00
# BUREAU_BUREAU_DEBT_RATIO_MEAN                    0.000000  1.862767e-01
# PREV_INST_RATIO_EARLY_MEAN                       0.766667  9.091252e-01
# PREV_INST_RATIO_LATE_MEAN                        0.000000  4.545455e-03
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX              6.000000  9.000000e+00
# PREV_INST_INST_DAYSLATE_MAX_MEAN                -7.000000 -2.500000e+00
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN              0.977666  1.025559e+00
# REGION_RATING_CLIENT_W_CITY                      2.000000  2.000000e+00
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX               1.000000  1.105603e+00
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM        0.000000  0.000000e+00
# PREV_CC_CC_UTILIZATION_MAX_MAX                   0.000000  6.820902e-01
# BUREAU_AMT_CREDIT_SUM_MAX                   188421.165000  4.702500e+05
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX        0.060241  2.692308e-01
# BUREAU_BUREAU_DEBT_RATIO_SUM                     0.000000  8.418039e-01
# DAYS_ID_PUBLISH                              -4448.000000 -3.234000e+03
# PREV_INST_COUNT_EARLY_SUM                       11.000000  2.000000e+01
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX                0.000000  0.000000e+00
# PREV_PREV_CREDIT_TO_APPLICATION_MAX              1.000000  1.105603e+00
# PREV_INST_COUNT_LATE_MEAN                        0.000000  1.428571e-01
# PREV_INST_RATIO_LATE_MIN                         0.000000  0.000000e+00
# BUREAU_CREDIT_TYPE_Microloan                     0.000000  0.000000e+00
# DEF_60_CNT_SOCIAL_CIRCLE                         0.000000  0.000000e+00
# PREV_INST_AMT_PAYMENT_SUM_SUM               143383.533750  3.537400e+05
# PREV_DAYS_DECISION_MEAN                      -1202.000000 -7.840000e+02
# PREV_POS_MONTHS_MAX_MAX                        -15.000000 -5.000000e+00
# BUREAU_DAYS_CREDIT_MEAN                      -1414.406250 -1.062944e+03
# PREV_INST_AMT_PAYMENT_SUM_MEAN               83253.217500  1.470080e+05
# PREV_RATIO_APPROVED                              0.500000  7.500000e-01
# BUREAU_AMT_CREDIT_SUM_MEAN                  107055.222188  2.079549e+05
# PREV_INST_COUNT_EARLY_MEAN                       6.000000  8.500000e+00
# PREV_INST_AMT_INSTALMENT_MIN_MIN              2320.425000  5.422500e+03
# PREV_INST_INST_DAYSLATE_MAX_MAX                 -3.000000  1.000000e+00
# BUREAU_CREDIT_TYPE_Mortgage                      0.000000  0.000000e+00
# BUREAU_DAYS_CREDIT_ENDDATE_MAX                 130.000000  9.240000e+02
# PREV_INST_RATIO_LATE_SUM                         0.000000  1.092929e-02
# BUREAU_BUREAU_REAL_DELAY_MEAN                 -273.000000 -3.270000e+01
# PREV_CC_CC_UTILIZATION_MAX_MEAN                  0.000000  6.643929e-01
# DAYS_LAST_PHONE_CHANGE                       -1766.250000 -8.630000e+02
# PREV_AMT_DOWN_PAYMENT_SUM                        0.000000  5.940000e+03
# PREV_CNT_PAYMENT_STD                             4.242641  8.485281e+00
# PREV_INST_AMT_PAYMENT_MIN_MAX                 7553.857500  1.388979e+04
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM                0.000000  0.000000e+00
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN       0.060241  2.690240e-01
# BUREAU_AMT_CREDIT_SUM_SUM                   368487.078750  1.090645e+06
# PREV_AMT_ANNUITY_MIN                          3498.795000  5.924745e+03
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN        0.058824  2.666667e-01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX            -225.000000  1.510000e+02
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN            31.000000  3.300000e+01
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN               0.000000  0.000000e+00
# BUREAU_DAYS_ENDDATE_FACT_MAX                  -683.000000 -3.420000e+02
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD                0.000000  0.000000e+00
# PREV_AMT_ANNUITY_MEAN                         8428.522500  1.279683e+04
# PREV_INST_INST_DAYSLATE_SUM_MAX                -95.000000 -5.000000e+01
# PREV_INST_RATIO_LATE_MAX                         0.000000  1.785714e-02
# PREV_CC_CC_UTILIZATION_MEAN_SUM                  0.000000  0.000000e+00
# PREV_CC_CC_UTILIZATION_MEAN_MEAN                 0.000000  1.338725e-01
# PREV_AMT_DOWN_PAYMENT_MAX                        0.000000  5.850000e+03
# BUREAU_AMT_CREDIT_SUM_MIN                    13923.000000  3.870000e+04
# PREV_INST_AMT_INSTALMENT_MIN_MEAN             7033.329000  1.096288e+04
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN            0.000000  6.710100e-01
# BUREAU_DAYS_CREDIT_MAX                        -637.000000 -3.270000e+02
# PREV_INST_COUNT_OVERPAID_STD                     0.000000  0.000000e+00
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN          -325.379688  0.000000e+00
# PREV_INST_INST_DAYSLATE_MAX_MIN                -13.000000 -8.000000e+00
# AMT_INCOME_TOTAL                            112500.000000  1.575000e+05
# PREV_SELLERPLACE_AREA_MEAN                      22.333333  7.900000e+01
# PREV_POS_SK_DPD_DEF_MAX_MEAN                     0.000000  0.000000e+00
# PREV_INST_AMT_PAYMENT_MIN_MIN                   57.015000  2.926800e+03
# PREV_INST_AMT_PAYMENT_SUM_MAX               107591.760000  2.145609e+05
# BUREAU_AMT_CREDIT_SUM_STD                    82447.664604  2.002832e+05
# PREV_INST_DAYS_INSTALMENT_MAX_STD              323.845224  6.011859e+02
# DEF_30_CNT_SOCIAL_CIRCLE                         0.000000  0.000000e+00
# PREV_CC_CC_UTILIZATION_MEAN_MAX                  0.000000  1.347524e-01
# PREV_INST_RATIO_EARLY_MAX                        1.000000  1.000000e+00
# PREV_INST_AMT_INSTALMENT_SUM_SUM            146473.143750  3.611484e+05
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX          -410.000000 -7.400000e+01
# AMT_REQ_CREDIT_BUREAU_QRT                        0.000000  0.000000e+00
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN          -3651.058125  0.000000e+00
# BUREAU_DAYS_CREDIT_SUM                       -9458.250000 -4.937000e+03
# BUREAU_DAYS_CREDIT_MIN                       -2584.000000 -1.803000e+03
# BUREAU_DAYS_ENDDATE_FACT_STD                   312.736311  5.203806e+02
# PREV_INST_DAYS_INSTALMENT_MAX_MAX             -399.000000 -5.700000e+01
# APARTMENTS_MODE                                  0.058800  8.510000e-02
# BUREAU_DAYS_CREDIT_UPDATE_MAX                  -39.000000 -1.700000e+01
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN        -25181.000000 -1.321100e+04
# PREV_INST_AMT_PAYMENT_MEAN_MIN                4534.118534  7.364922e+03
# PREV_INST_INST_DAYSLATE_MAX_SUM                -15.000000 -6.000000e+00
# PREV_INST_COUNT_OVERPAID_MEAN                    0.000000  0.000000e+00
# BUREAU_BUREAU_CREDIT_DURATION_MAX              732.000000  1.826000e+03
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN             7.111111  1.033333e+01
# PREV_CC_CC_UTILIZATION_MAX_SUM                   0.000000  0.000000e+00
# PREV_NAME_PRODUCT_TYPE_walk-in                   0.000000  0.000000e+00
# PREV_POS_SK_DPD_DEF_SUM_MEAN                     0.000000  0.000000e+00
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN              9.500000  1.200000e+01
# PREV_POS_STATUS_ACTIVE_RATIO_STD                 0.041788  6.549119e-02
# PREV_POS_STATUS_ACTIVE_MEAN                      6.500000  9.166667e+00
# PREV_INST_DAYS_INSTALMENT_SUM_MIN           -25030.000000 -1.304800e+04
# PREV_CNT_PAYMENT_MEAN                            9.000000  1.200000e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN           -765.350000 -1.891000e+02
# PREV_INST_AMT_PAYMENT_SUM_MIN                34753.410000  6.225624e+04
# PREV_POS_SK_DPD_DEF_MEAN_SUM                     0.000000  0.000000e+00
#
#                                                      75%           max
# SK_ID_CURR                                  3.675555e+05  4.562500e+05
# EXT_SOURCE_3                                6.528966e-01  8.825303e-01
# EXT_SOURCE_2                                6.584970e-01  8.549997e-01
# EXT_SOURCE_1                                6.659559e-01  9.391445e-01
# BUREAU_BUREAU_DEBT_RATIO_MAX                9.476186e-01  2.999900e+04
# DAYS_EMPLOYED                              -8.610000e+02 -1.000000e+00
# AMT_CREDIT                                  6.750000e+05  2.245500e+06
# PREV_RATIO_REFUSED                          2.000000e-01  1.000000e+00
# PREV_INST_AMT_PAYMENT_MIN_SUM               4.487199e+04  3.139280e+06
# AMT_ANNUITY                                 3.739050e+04  1.805760e+05
# PREV_INST_AMT_PAYMENT_MIN_MEAN              1.522644e+04  1.569640e+06
# AMT_GOODS_PRICE                             6.300000e+05  2.245500e+06
# DAYS_BIRTH                                 -1.249600e+04 -7.338000e+03
# OWN_CAR_AGE                                 1.500000e+01  7.400000e+01
# BUREAU_BUREAU_DEBT_RATIO_STD                4.387349e-01  8.320142e+03
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN        1.077891e+00  2.865696e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN        1.101178e+01  5.600000e+01
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD         8.321450e+00  3.995153e+01
# BUREAU_BUREAU_DEBT_RATIO_MEAN               3.585110e-01  2.307895e+03
# PREV_INST_RATIO_EARLY_MEAN                  1.000000e+00  1.000000e+00
# PREV_INST_RATIO_LATE_MEAN                   8.333333e-02  1.000000e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX         1.758333e+01  6.800000e+01
# PREV_INST_INST_DAYSLATE_MAX_MEAN            1.000000e+00  1.115000e+03
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN         1.077876e+00  2.336285e+00
# REGION_RATING_CLIENT_W_CITY                 2.000000e+00  3.000000e+00
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX          1.198000e+00  2.000000e+01
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM   0.000000e+00  1.700000e+01
# PREV_CC_CC_UTILIZATION_MAX_MAX              1.030612e+00  2.190730e+00
# BUREAU_AMT_CREDIT_SUM_MAX                   1.172788e+06  5.850000e+08
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX   6.923077e-01  1.700000e+01
# BUREAU_BUREAU_DEBT_RATIO_SUM                1.633174e+00  3.000264e+04
# DAYS_ID_PUBLISH                            -1.706000e+03  0.000000e+00
# PREV_INST_COUNT_EARLY_SUM                   3.700000e+01  2.210000e+02
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX           4.451355e+03  8.381349e+06
# PREV_PREV_CREDIT_TO_APPLICATION_MAX         1.198000e+00  2.000000e+01
# PREV_INST_COUNT_LATE_MEAN                   1.000000e+00  4.100000e+01
# PREV_INST_RATIO_LATE_MIN                    0.000000e+00  1.000000e+00
# BUREAU_CREDIT_TYPE_Microloan                0.000000e+00  3.900000e+01
# DEF_60_CNT_SOCIAL_CIRCLE                    0.000000e+00  2.400000e+01
# PREV_INST_AMT_PAYMENT_SUM_SUM               9.299500e+05  3.268928e+07
# PREV_DAYS_DECISION_MEAN                    -4.993125e+02 -5.000000e+00
# PREV_POS_MONTHS_MAX_MAX                    -2.000000e+00 -1.000000e+00
# BUREAU_DAYS_CREDIT_MEAN                    -7.091500e+02  0.000000e+00
# PREV_INST_AMT_PAYMENT_SUM_MEAN              2.906606e+05  5.448214e+06
# PREV_RATIO_APPROVED                         1.000000e+00  1.000000e+00
# BUREAU_AMT_CREDIT_SUM_MEAN                  4.200655e+05  5.537859e+07
# PREV_INST_COUNT_EARLY_MEAN                  1.133333e+01  9.400000e+01
# PREV_INST_AMT_INSTALMENT_MIN_MIN            9.955215e+03  1.230002e+06
# PREV_INST_INST_DAYSLATE_MAX_MAX             7.000000e+00  2.197000e+03
# BUREAU_CREDIT_TYPE_Mortgage                 0.000000e+00  4.000000e+00
# BUREAU_DAYS_CREDIT_ENDDATE_MAX              2.029250e+03  3.092600e+04
# PREV_INST_RATIO_LATE_SUM                    2.500000e-01  4.183354e+00
# BUREAU_BUREAU_REAL_DELAY_MEAN               0.000000e+00  2.405000e+03
# PREV_CC_CC_UTILIZATION_MAX_MEAN             1.030104e+00  2.190730e+00
# DAYS_LAST_PHONE_CHANGE                     -3.630000e+02  0.000000e+00
# PREV_AMT_DOWN_PAYMENT_SUM                   1.818112e+04  6.441543e+06
# PREV_CNT_PAYMENT_STD                        1.509967e+01  4.808326e+01
# PREV_INST_AMT_PAYMENT_MIN_MAX               2.529582e+04  3.116440e+06
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM           0.000000e+00  8.381349e+06
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN  6.885417e-01  1.700000e+01
# BUREAU_AMT_CREDIT_SUM_SUM                   2.656725e+06  6.091645e+08
# PREV_AMT_ANNUITY_MIN                        9.897390e+03  2.358750e+05
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN   6.842105e-01  1.700000e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX          3.652430e+05  3.652430e+05
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN        4.125000e+01  3.681450e+05
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN          1.629000e+03  7.431934e+06
# BUREAU_DAYS_ENDDATE_FACT_MAX               -1.580000e+02  0.000000e+00
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD           3.898465e+03  5.926509e+06
# PREV_AMT_ANNUITY_MEAN                       1.939945e+04  2.358750e+05
# PREV_INST_INST_DAYSLATE_SUM_MAX            -2.100000e+01  3.942900e+04
# PREV_INST_RATIO_LATE_MAX                    2.000000e-01  1.000000e+00
# PREV_CC_CC_UTILIZATION_MEAN_SUM             0.000000e+00  1.776696e+00
# PREV_CC_CC_UTILIZATION_MEAN_MEAN            5.442997e-01  1.198534e+00
# PREV_AMT_DOWN_PAYMENT_MAX                   1.416150e+04  2.118938e+06
# BUREAU_AMT_CREDIT_SUM_MIN                   8.878860e+04  5.175000e+07
# PREV_INST_AMT_INSTALMENT_MIN_MEAN           1.742679e+04  1.569640e+06
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN       2.350979e+00  4.973597e+01
# BUREAU_DAYS_CREDIT_MAX                     -1.850000e+02  0.000000e+00
# PREV_INST_COUNT_OVERPAID_STD                0.000000e+00  4.101219e+01
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN        0.000000e+00  2.025003e+05
# PREV_INST_INST_DAYSLATE_MAX_MIN            -2.000000e+00  1.115000e+03
# AMT_INCOME_TOTAL                            2.250000e+05  4.410000e+06
# PREV_SELLERPLACE_AREA_MEAN                  3.500000e+02  2.500000e+05
# PREV_POS_SK_DPD_DEF_MAX_MEAN                0.000000e+00  3.000000e+01
# PREV_INST_AMT_PAYMENT_MIN_MIN               8.033625e+03  1.230002e+06
# PREV_INST_AMT_PAYMENT_SUM_MAX               5.481180e+05  3.007314e+07
# BUREAU_AMT_CREDIT_SUM_STD                   4.696532e+05  1.756981e+08
# PREV_INST_DAYS_INSTALMENT_MAX_STD           9.048819e+02  1.990506e+03
# DEF_30_CNT_SOCIAL_CIRCLE                    0.000000e+00  3.400000e+01
# PREV_CC_CC_UTILIZATION_MEAN_MAX             5.478733e-01  1.198534e+00
# PREV_INST_RATIO_EARLY_MAX                   1.000000e+00  1.000000e+00
# PREV_INST_AMT_INSTALMENT_SUM_SUM            9.239017e+05  3.247978e+07
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX       -2.600000e+01 -1.000000e+00
# AMT_REQ_CREDIT_BUREAU_QRT                   1.000000e+00  7.000000e+00
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN         0.000000e+00  5.086116e+04
# BUREAU_DAYS_CREDIT_SUM                     -2.124000e+03  0.000000e+00
# BUREAU_DAYS_CREDIT_MIN                     -1.102000e+03  0.000000e+00
# BUREAU_DAYS_ENDDATE_FACT_STD                7.346003e+02  1.946665e+03
# PREV_INST_DAYS_INSTALMENT_MAX_MAX          -1.800000e+01 -1.000000e+00
# APARTMENTS_MODE                             1.502000e-01  1.000000e+00
# BUREAU_DAYS_CREDIT_UPDATE_MAX              -8.000000e+00  0.000000e+00
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN       -5.146000e+03  0.000000e+00
# PREV_INST_AMT_PAYMENT_MEAN_MIN              1.268582e+04  1.230002e+06
# PREV_INST_INST_DAYSLATE_MAX_SUM             3.000000e+00  2.470000e+03
# PREV_INST_COUNT_OVERPAID_MEAN               0.000000e+00  3.400000e+01
# BUREAU_BUREAU_CREDIT_DURATION_MAX           3.616000e+03  3.383100e+04
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN        1.500000e+01  3.416925e+04
# PREV_CC_CC_UTILIZATION_MAX_SUM              0.000000e+00  2.320813e+00
# PREV_NAME_PRODUCT_TYPE_walk-in              1.000000e+00  3.200000e+01
# PREV_POS_SK_DPD_DEF_SUM_MEAN                0.000000e+00  1.010000e+02
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN         1.800000e+01  6.000000e+01
# PREV_POS_STATUS_ACTIVE_RATIO_STD            1.026091e-01  7.071068e-01
# PREV_POS_STATUS_ACTIVE_MEAN                 1.200000e+01  9.200000e+01
# PREV_INST_DAYS_INSTALMENT_SUM_MIN          -4.992000e+03 -5.000000e+00
# PREV_CNT_PAYMENT_MEAN                       1.800000e+01  6.000000e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN         6.038921e+04  3.652430e+05
# PREV_INST_AMT_PAYMENT_SUM_MIN               1.167749e+05  4.934154e+06
# PREV_POS_SK_DPD_DEF_MEAN_SUM                0.000000e+00  1.271917e+01

# %% [markdown]
# Vérification des bornes pour les chiffres numériques

# %%
desc = X_api.describe().T  # (rows=features)

# bornes simples à partir du describe (min/max observés)
bounds = desc[["min", "max", "mean", "std"]].copy()
bounds
# Out:
#                                                       min           max  \
# SK_ID_CURR                                  100001.000000  4.562500e+05
# EXT_SOURCE_3                                     0.000527  8.825303e-01
# EXT_SOURCE_2                                     0.000008  8.549997e-01
# EXT_SOURCE_1                                     0.013458  9.391445e-01
# BUREAU_BUREAU_DEBT_RATIO_MAX                     0.000000  2.999900e+04
# DAYS_EMPLOYED                               -17463.000000 -1.000000e+00
# AMT_CREDIT                                   45000.000000  2.245500e+06
# PREV_RATIO_REFUSED                               0.000000  1.000000e+00
# PREV_INST_AMT_PAYMENT_MIN_SUM                    0.000000  3.139280e+06
# AMT_ANNUITY                                   2295.000000  1.805760e+05
# PREV_INST_AMT_PAYMENT_MIN_MEAN                   0.000000  1.569640e+06
# AMT_GOODS_PRICE                              45000.000000  2.245500e+06
# DAYS_BIRTH                                  -25195.000000 -7.338000e+03
# OWN_CAR_AGE                                      0.000000  7.400000e+01
# BUREAU_BUREAU_DEBT_RATIO_STD                     0.000000  8.320142e+03
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN             0.100000  2.865696e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN             0.000000  5.600000e+01
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD              0.000000  3.995153e+01
# BUREAU_BUREAU_DEBT_RATIO_MEAN                    0.000000  2.307895e+03
# PREV_INST_RATIO_EARLY_MEAN                       0.000000  1.000000e+00
# PREV_INST_RATIO_LATE_MEAN                        0.000000  1.000000e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX              0.000000  6.800000e+01
# PREV_INST_INST_DAYSLATE_MAX_MEAN               -81.333333  1.115000e+03
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN              0.100000  2.336285e+00
# REGION_RATING_CLIENT_W_CITY                     -1.000000  3.000000e+00
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX               0.100000  2.000000e+01
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM        0.000000  1.700000e+01
# PREV_CC_CC_UTILIZATION_MAX_MAX                   0.000000  2.190730e+00
# BUREAU_AMT_CREDIT_SUM_MAX                        0.000000  5.850000e+08
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX        0.000000  1.700000e+01
# BUREAU_BUREAU_DEBT_RATIO_SUM                     0.000000  3.000264e+04
# DAYS_ID_PUBLISH                              -6348.000000  0.000000e+00
# PREV_INST_COUNT_EARLY_SUM                        0.000000  2.210000e+02
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX                0.000000  8.381349e+06
# PREV_PREV_CREDIT_TO_APPLICATION_MAX              0.100000  2.000000e+01
# PREV_INST_COUNT_LATE_MEAN                        0.000000  4.100000e+01
# PREV_INST_RATIO_LATE_MIN                         0.000000  1.000000e+00
# BUREAU_CREDIT_TYPE_Microloan                     0.000000  3.900000e+01
# DEF_60_CNT_SOCIAL_CIRCLE                         0.000000  2.400000e+01
# PREV_INST_AMT_PAYMENT_SUM_SUM                    0.000000  3.268928e+07
# PREV_DAYS_DECISION_MEAN                      -2921.000000 -5.000000e+00
# PREV_POS_MONTHS_MAX_MAX                        -93.000000 -1.000000e+00
# BUREAU_DAYS_CREDIT_MEAN                      -2921.000000  0.000000e+00
# PREV_INST_AMT_PAYMENT_SUM_MEAN                   0.000000  5.448214e+06
# PREV_RATIO_APPROVED                              0.000000  1.000000e+00
# BUREAU_AMT_CREDIT_SUM_MEAN                       0.000000  5.537859e+07
# PREV_INST_COUNT_EARLY_MEAN                       0.000000  9.400000e+01
# PREV_INST_AMT_INSTALMENT_MIN_MIN                 0.000000  1.230002e+06
# PREV_INST_INST_DAYSLATE_MAX_MAX                -30.000000  2.197000e+03
# BUREAU_CREDIT_TYPE_Mortgage                      0.000000  4.000000e+00
# BUREAU_DAYS_CREDIT_ENDDATE_MAX               -2759.000000  3.092600e+04
# PREV_INST_RATIO_LATE_SUM                         0.000000  4.183354e+00
# BUREAU_BUREAU_REAL_DELAY_MEAN               -33286.000000  2.405000e+03
# PREV_CC_CC_UTILIZATION_MAX_MEAN                  0.000000  2.190730e+00
# DAYS_LAST_PHONE_CHANGE                       -4361.000000  0.000000e+00
# PREV_AMT_DOWN_PAYMENT_SUM                        0.000000  6.441543e+06
# PREV_CNT_PAYMENT_STD                             0.000000  4.808326e+01
# PREV_INST_AMT_PAYMENT_MIN_MAX                    0.000000  3.116440e+06
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM                0.000000  8.381349e+06
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN       0.000000  1.700000e+01
# BUREAU_AMT_CREDIT_SUM_SUM                        0.000000  6.091645e+08
# PREV_AMT_ANNUITY_MIN                             0.000000  2.358750e+05
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN        0.000000  1.700000e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX           -2796.000000  3.652430e+05
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN             1.000000  3.681450e+05
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN               0.000000  7.431934e+06
# BUREAU_DAYS_ENDDATE_FACT_MAX                 -2857.000000  0.000000e+00
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD                0.000000  5.926509e+06
# PREV_AMT_ANNUITY_MEAN                          885.780000  2.358750e+05
# PREV_INST_INST_DAYSLATE_SUM_MAX              -5566.000000  3.942900e+04
# PREV_INST_RATIO_LATE_MAX                         0.000000  1.000000e+00
# PREV_CC_CC_UTILIZATION_MEAN_SUM                 -0.002887  1.776696e+00
# PREV_CC_CC_UTILIZATION_MEAN_MEAN                -0.002887  1.198534e+00
# PREV_AMT_DOWN_PAYMENT_MAX                        0.000000  2.118938e+06
# BUREAU_AMT_CREDIT_SUM_MIN                        0.000000  5.175000e+07
# PREV_INST_AMT_INSTALMENT_MIN_MEAN                0.450000  1.569640e+06
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN            0.000000  4.973597e+01
# BUREAU_DAYS_CREDIT_MAX                       -2921.000000  0.000000e+00
# PREV_INST_COUNT_OVERPAID_STD                     0.000000  4.101219e+01
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN        -89733.145500  2.025003e+05
# PREV_INST_INST_DAYSLATE_MAX_MIN               -241.000000  1.115000e+03
# AMT_INCOME_TOTAL                             26941.500000  4.410000e+06
# PREV_SELLERPLACE_AREA_MEAN                      -1.000000  2.500000e+05
# PREV_POS_SK_DPD_DEF_MAX_MEAN                     0.000000  3.000000e+01
# PREV_INST_AMT_PAYMENT_MIN_MIN                    0.000000  1.230002e+06
# PREV_INST_AMT_PAYMENT_SUM_MAX                    0.000000  3.007314e+07
# BUREAU_AMT_CREDIT_SUM_STD                        0.000000  1.756981e+08
# PREV_INST_DAYS_INSTALMENT_MAX_STD                0.000000  1.990506e+03
# DEF_30_CNT_SOCIAL_CIRCLE                         0.000000  3.400000e+01
# PREV_CC_CC_UTILIZATION_MEAN_MAX                 -0.002887  1.198534e+00
# PREV_INST_RATIO_EARLY_MAX                        0.000000  1.000000e+00
# PREV_INST_AMT_INSTALMENT_SUM_SUM                 0.000000  3.247978e+07
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX         -2859.000000 -1.000000e+00
# AMT_REQ_CREDIT_BUREAU_QRT                        0.000000  7.000000e+00
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN        -223029.000000  5.086116e+04
# BUREAU_DAYS_CREDIT_SUM                      -83611.000000  0.000000e+00
# BUREAU_DAYS_CREDIT_MIN                       -2922.000000  0.000000e+00
# BUREAU_DAYS_ENDDATE_FACT_STD                     0.000000  1.946665e+03
# PREV_INST_DAYS_INSTALMENT_MAX_MAX            -2850.000000 -1.000000e+00
# APARTMENTS_MODE                                  0.000000  1.000000e+00
# BUREAU_DAYS_CREDIT_UPDATE_MAX                -2907.000000  0.000000e+00
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN       -300606.000000  0.000000e+00
# PREV_INST_AMT_PAYMENT_MEAN_MIN                   0.090000  1.230002e+06
# PREV_INST_INST_DAYSLATE_MAX_SUM               -244.000000  2.470000e+03
# PREV_INST_COUNT_OVERPAID_MEAN                    0.000000  3.400000e+01
# BUREAU_BUREAU_CREDIT_DURATION_MAX                0.000000  3.383100e+04
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN             0.000000  3.416925e+04
# PREV_CC_CC_UTILIZATION_MAX_SUM                   0.000000  2.320813e+00
# PREV_NAME_PRODUCT_TYPE_walk-in                   0.000000  3.200000e+01
# PREV_POS_SK_DPD_DEF_SUM_MEAN                     0.000000  1.010000e+02
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN              0.000000  6.000000e+01
# PREV_POS_STATUS_ACTIVE_RATIO_STD                 0.000000  7.071068e-01
# PREV_POS_STATUS_ACTIVE_MEAN                      0.000000  9.200000e+01
# PREV_INST_DAYS_INSTALMENT_SUM_MIN          -299543.000000 -5.000000e+00
# PREV_CNT_PAYMENT_MEAN                            0.000000  6.000000e+01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN          -2796.000000  3.652430e+05
# PREV_INST_AMT_PAYMENT_SUM_MIN                    0.000000  4.934154e+06
# PREV_POS_SK_DPD_DEF_MEAN_SUM                     0.000000  1.271917e+01
#
#                                                     mean           std
# SK_ID_CURR                                  2.777967e+05  1.031695e+05
# EXT_SOURCE_3                                5.001056e-01  1.894980e-01
# EXT_SOURCE_2                                5.180211e-01  1.812781e-01
# EXT_SOURCE_1                                5.011798e-01  2.051423e-01
# BUREAU_BUREAU_DEBT_RATIO_MAX                3.039704e+00  1.678111e+02
# DAYS_EMPLOYED                              -2.476739e+03  2.307964e+03
# AMT_CREDIT                                  5.167404e+05  3.653970e+05
# PREV_RATIO_REFUSED                          1.145769e-01  1.798921e-01
# PREV_INST_AMT_PAYMENT_MIN_SUM               4.599559e+04  1.097801e+05
# AMT_ANNUITY                                 2.942624e+04  1.601637e+04
# PREV_INST_AMT_PAYMENT_MIN_MEAN              1.508186e+04  3.312666e+04
# AMT_GOODS_PRICE                             4.626188e+05  3.367102e+05
# DAYS_BIRTH                                 -1.606808e+04  4.325900e+03
# OWN_CAR_AGE                                 1.178603e+01  1.146289e+01
# BUREAU_BUREAU_DEBT_RATIO_STD                1.245993e+00  5.562186e+01
# PREV_PREV_CREDIT_TO_APPLICATION_MEAN        1.020343e+00  9.777146e-02
# PREV_POS_INSTALMENT_FUTURE_MEAN_MEAN        8.937964e+00  5.991956e+00
# PREV_POS_INSTALMENT_FUTURE_MEAN_STD         6.136017e+00  6.168549e+00
# BUREAU_BUREAU_DEBT_RATIO_MEAN               5.129628e-01  1.666635e+01
# PREV_INST_RATIO_EARLY_MEAN                  8.596568e-01  1.605712e-01
# PREV_INST_RATIO_LATE_MEAN                   5.844804e-02  9.568376e-02
# PREV_POS_INSTALMENT_FUTURE_MEAN_MAX         1.373659e+01  1.148673e+01
# PREV_INST_INST_DAYSLATE_MAX_MEAN            4.082260e-02  3.019590e+01
# PREV_PREV_CREDIT_TO_GOODSPRICE_MEAN         1.020299e+00  9.746636e-02
# REGION_RATING_CLIENT_W_CITY                 2.012596e+00  5.158041e-01
# PREV_PREV_CREDIT_TO_GOODSPRICE_MAX          1.111273e+00  1.811360e-01
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_SUM   9.709977e-02  3.694545e-01
# PREV_CC_CC_UTILIZATION_MAX_MAX              5.422329e-01  4.863603e-01
# BUREAU_AMT_CREDIT_SUM_MAX                   1.089840e+06  3.415317e+06
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MAX   5.091874e-01  7.097003e-01
# BUREAU_BUREAU_DEBT_RATIO_SUM                3.445678e+00  1.656008e+02
# DAYS_ID_PUBLISH                            -3.051713e+03  1.569277e+03
# PREV_INST_COUNT_EARLY_SUM                   2.732787e+01  2.377952e+01
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MAX           6.584804e+03  7.978567e+04
# PREV_PREV_CREDIT_TO_APPLICATION_MAX         1.111486e+00  1.830489e-01
# PREV_INST_COUNT_LATE_MEAN                   9.739729e-01  1.891791e+00
# PREV_INST_RATIO_LATE_MIN                    2.131307e-02  7.523413e-02
# BUREAU_CREDIT_TYPE_Microloan                8.052930e-02  8.280617e-01
# DEF_60_CNT_SOCIAL_CIRCLE                    1.011393e-01  4.037912e-01
# PREV_INST_AMT_PAYMENT_SUM_SUM               7.422276e+05  9.904318e+05
# PREV_DAYS_DECISION_MEAN                    -9.175523e+02  5.553682e+02
# PREV_POS_MONTHS_MAX_MAX                    -1.214407e+01  1.721768e+01
# BUREAU_DAYS_CREDIT_MEAN                    -1.088503e+03  5.269829e+02
# PREV_INST_AMT_PAYMENT_SUM_MEAN              2.342612e+05  2.538890e+05
# PREV_RATIO_APPROVED                         7.179468e-01  2.672446e-01
# BUREAU_AMT_CREDIT_SUM_MEAN                  3.972991e+05  7.976595e+05
# PREV_INST_COUNT_EARLY_MEAN                  9.369381e+00  5.058246e+00
# PREV_INST_AMT_INSTALMENT_MIN_MIN            8.131514e+03  1.658134e+04
# PREV_INST_INST_DAYSLATE_MAX_MAX             9.562300e+00  7.211117e+01
# BUREAU_CREDIT_TYPE_Mortgage                 6.578450e-02  2.719968e-01
# BUREAU_DAYS_CREDIT_ENDDATE_MAX              4.979068e+03  9.844671e+03
# PREV_INST_RATIO_LATE_SUM                    1.753976e-01  3.021562e-01
# BUREAU_BUREAU_REAL_DELAY_MEAN              -5.020158e+02  1.842236e+03
# PREV_CC_CC_UTILIZATION_MAX_MEAN             5.404827e-01  4.856423e-01
# DAYS_LAST_PHONE_CHANGE                     -1.077766e+03  8.789207e+02
# PREV_AMT_DOWN_PAYMENT_SUM                   1.602647e+04  4.926010e+04
# PREV_CNT_PAYMENT_STD                        1.025658e+01  7.550866e+00
# PREV_INST_AMT_PAYMENT_MIN_MAX               3.119308e+04  9.635192e+04
# BUREAU_AMT_CREDIT_MAX_OVERDUE_SUM           5.359891e+03  6.702934e+04
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MEAN  5.074497e-01  7.071757e-01
# BUREAU_AMT_CREDIT_SUM_SUM                   2.220714e+06  4.537975e+06
# PREV_AMT_ANNUITY_MIN                        8.209044e+03  8.263579e+03
# PREV_CC_CNT_DRAWINGS_ATM_CURRENT_MEAN_MIN   5.057120e-01  7.067582e-01
# PREV_DAYS_LAST_DUE_1ST_VERSION_MAX          1.120770e+05  1.685887e+05
# PREV_PREV_DECISION_TO_FIRST_DUE_MEAN        1.459370e+04  4.166299e+04
# BUREAU_AMT_CREDIT_MAX_OVERDUE_MEAN          3.503427e+03  6.344184e+04
# BUREAU_DAYS_ENDDATE_FACT_MAX               -5.056957e+02  5.028758e+02
# BUREAU_AMT_CREDIT_MAX_OVERDUE_STD           4.145082e+03  4.705389e+04
# PREV_AMT_ANNUITY_MEAN                       1.541084e+04  1.057334e+04
# PREV_INST_INST_DAYSLATE_SUM_MAX            -6.644297e+01  2.384695e+02
# PREV_INST_RATIO_LATE_MAX                    1.189454e-01  1.657438e-01
# PREV_CC_CC_UTILIZATION_MEAN_SUM             8.534943e-02  2.218415e-01
# PREV_CC_CC_UTILIZATION_MEAN_MEAN            2.839476e-01  3.252968e-01
# PREV_AMT_DOWN_PAYMENT_MAX                   1.228880e+04  2.954744e+04
# BUREAU_AMT_CREDIT_SUM_MIN                   1.145575e+05  5.172363e+05
# PREV_INST_AMT_INSTALMENT_MIN_MEAN           1.712839e+04  3.279299e+04
# PREV_CC_CNT_DRAWINGS_CURRENT_STD_MEAN       1.956272e+00  3.416548e+00
# BUREAU_DAYS_CREDIT_MAX                     -5.011833e+02  5.075073e+02
# PREV_INST_COUNT_OVERPAID_STD                3.873136e-01  1.243440e+00
# PREV_INST_INST_PAYMENTDIFF_MEAN_MEAN        7.268850e+02  6.019692e+03
# PREV_INST_INST_DAYSLATE_MAX_MIN            -7.187553e+00  1.763567e+01
# AMT_INCOME_TOTAL                            1.784318e+05  1.015226e+05
# PREV_SELLERPLACE_AREA_MEAN                  4.124655e+02  2.409429e+03
# PREV_POS_SK_DPD_DEF_MAX_MEAN                3.195973e-01  1.412206e+00
# PREV_INST_AMT_PAYMENT_MIN_MIN               6.232510e+03  1.659524e+04
# PREV_INST_AMT_PAYMENT_SUM_MAX               4.423748e+05  5.734117e+05
# BUREAU_AMT_CREDIT_SUM_STD                   4.496771e+05  1.226472e+06
# PREV_INST_DAYS_INSTALMENT_MAX_STD           6.365931e+02  3.850143e+02
# DEF_30_CNT_SOCIAL_CIRCLE                    1.436519e-01  5.144128e-01
# PREV_CC_CC_UTILIZATION_MEAN_MAX             2.851661e-01  3.261981e-01
# PREV_INST_RATIO_EARLY_MAX                   9.550787e-01  1.219737e-01
# PREV_INST_AMT_INSTALMENT_SUM_SUM            7.269910e+05  9.446391e+05
# PREV_INST_DAYS_ENTRY_PAYMENT_MAX_MAX       -3.322957e+02  5.239280e+02
# AMT_REQ_CREDIT_BUREAU_QRT                   5.469024e-01  6.933054e-01
# PREV_INST_INST_PAYMENTDIFF_MIN_MEAN        -2.930058e+03  6.314749e+03
# BUREAU_DAYS_CREDIT_SUM                     -6.724937e+03  6.254762e+03
# BUREAU_DAYS_CREDIT_MIN                     -1.776740e+03  8.299411e+02
# BUREAU_DAYS_ENDDATE_FACT_STD                5.355903e+02  3.022448e+02
# PREV_INST_DAYS_INSTALMENT_MAX_MAX          -3.230409e+02  5.248757e+02
# APARTMENTS_MODE                             1.190780e-01  1.134647e-01
# BUREAU_DAYS_CREDIT_UPDATE_MAX              -1.288561e+02  3.183699e+02
# PREV_INST_DAYS_ENTRY_PAYMENT_SUM_MIN       -2.040541e+04  2.756906e+04
# PREV_INST_AMT_PAYMENT_MEAN_MIN              1.206789e+04  2.231350e+04
# PREV_INST_INST_DAYSLATE_MAX_SUM             8.707113e-01  7.577240e+01
# PREV_INST_COUNT_OVERPAID_MEAN               2.432230e-01  1.021813e+00
# BUREAU_BUREAU_CREDIT_DURATION_MAX           5.819137e+03  9.905270e+03
# PREV_INST_INST_PAYMENTRATIO_SUM_MEAN        1.576228e+01  1.898137e+02
# PREV_CC_CC_UTILIZATION_MAX_SUM              1.624554e-01  3.658138e-01
# PREV_NAME_PRODUCT_TYPE_walk-in              4.603975e-01  1.081010e+00
# PREV_POS_SK_DPD_DEF_SUM_MEAN                5.261976e-01  2.707816e+00
# PREV_POS_INSTALMENT_FUTURE_MAX_MEAN         1.445438e+01  7.702938e+00
# PREV_POS_STATUS_ACTIVE_RATIO_STD            8.452176e-02  7.338888e-02
# PREV_POS_STATUS_ACTIVE_MEAN                 9.952016e+00  4.978497e+00
# PREV_INST_DAYS_INSTALMENT_SUM_MIN          -2.025565e+04  2.752877e+04
# PREV_CNT_PAYMENT_MEAN                       1.454900e+01  8.342980e+00
# PREV_DAYS_LAST_DUE_1ST_VERSION_MEAN         3.248992e+04  5.781678e+04
# PREV_INST_AMT_PAYMENT_SUM_MIN               1.069361e+05  1.665503e+05
# PREV_POS_SK_DPD_DEF_MEAN_SUM                1.112126e-01  5.062794e-01

# %% [markdown]
# ## Récuperer le modèle + artifacts

# %%
import os
import shutil

RUN_ID = "a4dc7831df1b42a4a363af56bc86a775"

SRC_RUN_DIR = PROJECT_ROOT / "artifacts" / RUN_ID/"artifacts"
DEST_DIR = PROJECT_ROOT/"app"/"assets"

os.makedirs(DEST_DIR, exist_ok=True)

# Copier le dossier model
shutil.copytree(
    f"{SRC_RUN_DIR}/model",
    f"{DEST_DIR}/model",
    dirs_exist_ok=True
)

# Copier le dossier api_artifacts
shutil.copytree(
    f"{SRC_RUN_DIR}/api_artifacts",
    f"{DEST_DIR}/api_artifacts",
    dirs_exist_ok=True
)

print("Copie terminée vers app/assets/")
# Out:
# Copie terminée vers app/assets/
